# %% [markdown]
# #                                    *Rasa Chat Bot Assignment*

# %% [markdown]
# 1.	Prerequisites:
#     *PyCharm
#     *Visual C++ build tools: I’m working on windows environment, so I must install Visual C++ build tools. This is required for some python packages. So, I installed the below files: a) visualcppbuildtools_full.exe b) vs_BuildTools.exe c) vs_buildtools_199099402.15545467506.exe.

# %% [markdown]
#  2. In PyCharm, I opened a new project and named as weatherbot_rasa1 then I setup the environment as condo, python 3.6.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/pythoninter.png")

# %% [markdown]
# 3.	In the terminal run the below commands:
#         * pip install rasa-x -i https://pypi.rasa.com/simple --user
#         * pip install rasa_nlu[spacy]
#         * python -m spacy download en_core_web_md
#         * python -m spacy link en_core_web_md en

# %% [markdown]
# 4.	After successful installation of rasa-x and spacy, try to run the below command.
#         * python -m rasa init.
# This command helps us to create rasa default files like nlu.md, stories.md, config.yml, credentials.yml, domain.yml, endpoints.yml, _init_.py.

# %% [markdown]
# 5.	If you want to run rasa default files, we can run ‘rasa shell’ to talk with the bot. If we want to implement our own logic via program, we need to change the input of all the files. In my case, I like to predict the weather. So, I need weather api to access the current weather. For that I went to openweathermap.org and registered.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/openweather_login_1.png")

# %% [markdown]
# 6.	After sign up, I registered for current weather free plan.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/openweather_current.png")

# %% [markdown]
# 7.	I got the current weather API key.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/openweather_apikey.png")

# %% [markdown]
# 8.	After ‘rasa init’ command, we got the default files from rasa. So, nlu.md I changed the intent, in domain.yml I changed the actions, uncomment the action_endpoint in endpoints.yml. Likewise, I changed all the files and added my actions.py, weather_report.py file. In the weather report file contains API, which we get from openweathermap.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/weather_report.png")

# %% [markdown]
# 9.	We made a lot of changes in the project files. So, we need to train again. Run the below command.
#                 * rasa train.
# I used debug mode to understand step by step process.

# %% [markdown]
# 10.	After training we must run the server so use the below command to run.
#                 * rasa run --debug

# %% [markdown]
# 11.	After training we have to talk with our bot so, I run the below command.
#                 * rasa shell –debug

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/delhi-shell.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/kolkata-shell.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/chennai.png")
# temperature showing for chennai in debug mode.

# %% [markdown]
# 12.	Now we must start the rasa action server. Here is the command:
#             * rasa run actions –debug

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/rasarunactions.png")

# %% [markdown]
# 13.	I like to check my bot in user interface mode, so I used rasa x.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/rasa_portal.png")

# %% [markdown]
# 14.	When I click on the link where the server is running, I got the below outputs:

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/botresponse_rasax.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/botresponse_rasax1.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/botresponse_rasax2.png")

# %% [markdown]
# 15.	As of now my weather bot is working fine in locally with help of rasa. I like to deploy my bot in telegram. So, I need to upload my project to cloud and then I integrate my bot project with app like telegram. Here I used ngrok.
#             * ngrok http 5005

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/ngrok.png")

# %% [markdown]
# 16.	In Telegram, search BotFather then I created my own bot with the name of weather_rasa1bot.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/botcretion_telegram.png")

# %% [markdown]
# 17.	In credentials.yml file, I entered telegram token key, my bot name and weburl. The weburl is which we got it from ngrok.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/telegram_link.png")

# %% [markdown]
# 18.	After the changes, we must stop the terminal and again we have to start the rasa run actions and rasa run.

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/telegram_link_1.png")

# %% [markdown]
# 19. Next, we can go to telegram to check our bot. Here is the screenshot of my outputs:

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/firstoutput_telegram.png")

# %%
from IPython.display import Image
Image(filename="C:/devi/machine-learning/Rasa_chatbot/rasa/secondoutput_telegram.png")

# %% [markdown]
# 20.	 From above all the steps I successfully deployed my own weather bot in RASA.
